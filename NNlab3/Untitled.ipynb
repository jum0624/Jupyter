# %%
# %matplotlib inline
import matplotlib.pyplot
import imageio
import glob

for image_file_name in glob.glob('C:/Users/Prof_Baek/Desktop/git_repos/Jupyter/NNlab3/3'):
    correct_label = int(image_file_name[-5:-4])
    print("***correct_label : ", correct_label)
    
    image_array = imageio.imread(image_file_name)
    
    matplotlib.pyplot.imshow(image_array, cmap='Reds', interpolation = 'None')
    matplotlib.pyplot.show()
    
    image_array = image_array[:,:,0]
    print(image_array.shape)
    print(image_array)
    
    image_data = 255.0 - image_array.reshape(784)
    image_data = (image_data/255.0*0.99)
    
    matplotlib.pyplot.imshow(image_array, cmap='Reds', imterpolation = 'None')
    matplotlib.pyplot.show()

# %%
import numpy as np

np.random.rand(3,3)
# Out:
# array([[0.69834571, 0.62919417, 0.18735901],
#        [0.04915286, 0.89330358, 0.53189231],
#        [0.87853508, 0.70927662, 0.68169347]])
